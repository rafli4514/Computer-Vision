# %%
import numpy as np
import scipy
from scipy import ndimage
from PIL import Image
import matplotlib.pyplot as plt

# %%
file_name = 'Images/Screenshot 2025-03-18 093855.png'

image = Image.open(file_name)
image = np.array(image).astype("int32")

# %%
prewitt_h = ndimage.prewitt(image, axis=0)
prewitt_v = ndimage.prewitt(image, axis=1)
magnitude = np.sqrt(prewitt_h ** 2 + prewitt_v ** 2)
magnitude *= 255 / np.max(magnitude)

# %%
fig, axs = plt.subplots(2, 2, figsize=(4, 4))
plt.gray()
axs[0, 0].imshow(image)
axs[0, 1].imshow(prewitt_h)
axs[1, 0].imshow(prewitt_v)
axs[1, 1].imshow(magnitude)
titles = ["Original", "Horizontal", "Vertical", "Magnitude"]
for i, ax in enumerate(axs.ravel()):
    ax.set_title(titles[i])
    ax.axis("off")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-912..1278].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1041..1302].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
