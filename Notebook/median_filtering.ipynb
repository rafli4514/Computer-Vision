# %%
import os
import numpy as np
# import tkinter as tk
# from tkinter import filedialog
import scipy
import matplotlib.pyplot as plt
from scipy import ndimage
from PIL import Image

# %%
file_name = 'Images/Screenshot 2025-03-11 091107.png'

image = Image.open(file_name).convert('L')

# %%
filter_image = ndimage.median_filter(
    image, 
    size=3, 
    footprint=None, 
    output=None, 
    mode='reflect', 
    cval=0.0, 
    origin=0
)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].imshow(image, cmap='gray')
axes[0].set_title("Original")
axes[0].axis('off')
axes[1].imshow(filter_image, cmap='gray')
axes[1].set_title("Median filter")
axes[1].axis('off')
# Out:
# (np.float64(-0.5), np.float64(250.5), np.float64(251.5), np.float64(-0.5))
